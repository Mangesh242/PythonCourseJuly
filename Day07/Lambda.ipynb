# %%
#lambda functions

# %%
#Syntax :  lambda x : expressions

# %%
square= lambda no: no**2

# %%
print(square(2))
# Out:
# 4

# %%
#Functions : Map

# %%
list1=[2,4,6,8,1]

# %%
squares = list(map(lambda x: x**2, list1))

# %%
squares
# Out:
# [4, 16, 36, 64, 1]

# %%
#Filter

# %%
filteredList = list(filter(lambda x: x<5,list1))

# %%
#Traditional use 
# for i in list1:
#     if i >= 5 :
#         filteredList.append(i)

# %%
filteredList
# Out:
# [2, 4, 1]

# %%
#Sorted

# %%
studentList=[{"name":"Chaitanya","age":19},{"name":"Rohan","age":18}]

# %%
sortedList=sorted(studentList, key= lambda x : x['age'])

# %%
sortedList
# Out:
# [{'name': 'Rohan', 'age': 18}, {'name': 'Chaitanya', 'age': 19}]
