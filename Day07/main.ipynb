# %%
1 : Show all student
2 : Show grades 
from student import showGrades
from student import *
showGrades()
# Out:
#   Cell In[1], line 1
#     1 : Show all student
#     ^
# SyntaxError: illegal target for annotation
