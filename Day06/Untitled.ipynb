# %%
#Switch

# %%
Switch board : 2 number la fan will start
# Out:
#   Cell In[2], line 1
#     Switch board : 2 number la fan will start
#            ^
# SyntaxError: invalid syntax

# %%
#calculate
a=10
b=10
operator='-'


if operator == '+':
    print(a+b)
elif operator == '-':
    print(a-b)
elif operator == '*':
    print(a*b)
elif operator == '/':
    print(a/b)
elif operator == '%':
    print(a%b)
# Out:
# 0

# %%
#Syntax for switch case in python
match operator:
    case '+':
        #code block
    case '-':
        #code block
# Out:
#   Cell In[5], line 4
#     #code block
#                ^
# SyntaxError: incomplete input

# %%
no1=100
no2=50

# %%
operator=input("Enter operator:")
match operator:
    case '+':
        print(no1+no2)
    case '-':
        print(no1-no2)
# Out:
# Enter operator: +
# 150
