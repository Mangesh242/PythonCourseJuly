# %% [raw]
# Operators

# %%
no1=10

# %%
no2=12
no1String='10'
no2String='12'

sum=no1+no2
print(sum)
print(type(sum))
sum=no1String+no2String
print(sum)

print(type(sum))
# Out:
# 22
# <class 'int'>
# 1012
# <class 'str'>

# %%
#type() function is used for checking it's data type

# %%
sub=no1-no2
mul=no1*no2
div=no1/no2
divd=no1//no2

# %%
print(sub," ",mul," ",div," ",divd)
# Out:
# -2   120   0.8333333333333334   0

# %%
no1=12
no2=3 

ans=no1%no2
print(ans)
# Out:
# 0
