# %%
#Eligible for voting

# %%
age=int(input("Enter your age"))
# Out:
# Enter your age 16

# %%
#Indentation  :  Blank space at the start of written line , 4 spaces (tab)

# %%
if condition:
    #logic
# Out:
#   Cell In[3], line 1
#     if condition:
#                  ^
# SyntaxError: incomplete input

# %%
if age >= 18:
    print("eligible for voting")
# Out:
# eligible for voting

# %%
if age >= 18:
    print("Eligible for voting")
else:
    print("Not eligible")
# Out:
# No eligible

# %%
marks=180

# %%
#Maximum marks : 100, input range : 0 to 100 inclusive
if marks < 60:
    print("Grade C")
elif marks >=60 and marks < 80:
    print("Grade B")

elif marks >=80 and marks<=100:
    print("Grade A")
else:
    print("Invalid marks")
# Out:
# Invalid marks

# %%
#employe with age > 18 and with skill in programming

# %%
emp = { "name":"ABC", 'age':19, 'skill':'programming'}

# %%
if emp["age"] > 18:
    if emp["skill"] == 'programming':
        print("Eligible")
# Out:
# Eligible
