# %%
fruits=["apple", "banana", "cherry"]

# %%
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %%
emp = { "name":"ABC", 'age':19, 'skill':'programming'}

# %%
for key in emp.keys():
    print(emp[key]," ",key)
# Out:
# ABC   name
# 19   age
# programming   skill

# %%
emp.get("name1")

# %%
#error handling 
try: 
    print(emp["name4"])
except:
    print("Key not found")
# Out:
# Key not found

# %%
emp["name3"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 emp["name3"]
#
# KeyError: 'name3'

# %%
count = 0
while count < 3:
    print("Hello")
    count += 1
# Out:
# Hello
# Hello
# Hello

# %%
#tuple

# %%
tuple1=('give','me','sunshine')

# %%
for x in tuple1:
    print(x)
# Out:
# give
# me
# sunshine

# %%
name="This is python course"
for x in name:
    print(x)
# Out:
# T
# h
# i
# s
#
# i
# s
#
# p
# y
# t
# h
# o
# n
#
# c
# o
# u
# r
# s
# e

# %%
dictionary={"name":"ABC", "marks":45}

# %%
for key in dictionary.keys():
    print("key ", key , " value: ",dictionary[key])
# Out:
# key  name  value:  ABC
# key  marks  value:  45

# %%
set = {10,30,40,50}

# %%
for no in set:
    print(no)
# Out:
# 40
# 10
# 50
# 30

# %%
#Range :

# %%
#Range : [10,50] . Sequence from one no to another

# %%
#range(start,end,stepper) 
for num in range(0,11,2):
    print(num)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
#Break and continue

# %%
for num in range(0,10):
    print(num)
    if num == 5 :
        break
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
# Continue : Next code block get's skipped if condition met and it goes to next iteration
33 marks hawe ahet, 3 subject : 1 subject 25 : 
3 students
# Out:
#   Cell In[43], line 2
#     33 marks hawe ahet, 3 subject : 1 subject 25 :
#        ^
# SyntaxError: invalid syntax

# %%
for i in range(0,3):
    marks1=int(input("Enter first marks"))
    if marks1 < 33:
        continue
    marks2=int(input("Enter second marks"))
    marks3=int(input("Enter third marks"))
# Out:
# Enter first marks 45
# Enter second marks 45
# Enter third marks 45
# Enter first marks 25
