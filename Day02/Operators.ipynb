# %%
#operators

# %%
no1=10
no2=12

# %%
sum=no1+no2
sub=no1-no2
mul=no1*no2

# %%
div=no1/no2

# %%
print("sum :",sum," sub: ", sub, " Mul :",mul, "div :", div)
# Out:
# sum : 22  sub:  -2  Mul : 120 div : 0.8333333333333334

# %%
#Exponentiation operator 
print(2**3)
# Out:
# 8
