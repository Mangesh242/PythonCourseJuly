# %% [markdown]
# Day02 Basic Concepts

# %% [markdown]
# Keywords : Reserved words created by python

# %%
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# Identifier : Name used for variables, functions, classes, etc.

# %%
age = 20

# %%
print(age)
# Out:
# 20

# %%
and=20
# Out:
#   Cell In[7], line 1
#     and=20
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# Above code line gave error as we cannot use keyword as a identifier

# %%
# Comment : Above code line gave error as we cannot use keyword as a identifie

# %%
#Rules:

# %%
first name= 'Mangesh'
# Out:
#   Cell In[11], line 1
#     first name= 'Mangesh'
#           ^
# SyntaxError: invalid syntax

# %%
# These characters can be used to create Identifier : A-Z, a-z,0-9, _

# %%
Apple='red'

# %%
Apple12='Red'

# %%
fruits_='apple'

# %%
fruits_@='apple'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 fruits_@='apple'
#
# TypeError: unsupported operand type(s) for @=: 'str' and 'str'

# %%
1apple='red'
# Out:
#   Cell In[18], line 1
#     1apple='red'
#     ^
# SyntaxError: invalid decimal literal

# %%
_fruit='apple'

# %%
#Case Sensitive

# %%
print("world world")
# Out:
# world world

# %%
Print("Hello World")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 Print("Hello World")
#
# NameError: name 'Print' is not defined

# %%
no=10

# %%
No=12

# %%
print(no)
# Out:
# 10

# %%
print(No)
# Out:
# 12

# %%
#Print statment

# %%
print("Hello"," World")
# Out:
# Hello  World

# %%
print("Hello"," World","Hello"," World","Hello"," World")
# Out:
# Hello  World Hello  World Hello  World

# %%
print("This is first line","\nThis is second line")
# Out:
# This is first line
# This is second line

# %%
#\n is used for the next line .

# %%
#Home work : print statement findout equivalent things

# %%
#Assignment :
#1.Write a program to input 2 numbers and print their sum.

# %%
no1 = input()
# Out:
#  100

# %%
print(no1)
# Out:
# 100

# %%
no1 = int(input("Enter first number"))
print("First number entered is : ",no1)
# Out:
# Enter first number 213
# First number entered is :  213

# %%
no2=int(input("Enter second number"))
print("Second number entered is : ",no2)
# Out:
# Enter second number 2
# Second number entered is :  2

# %%
sum=no1+no2

# %%
print("sum of two number : ",sum)
# Out:
# sum of two number :  215

# %%
7pythonbatch='10students'
# Out:
#   Cell In[49], line 1
#     7pythonbatch='10students'
#     ^
# SyntaxError: invalid decimal literal

# %%
Google_BATCH="space"
