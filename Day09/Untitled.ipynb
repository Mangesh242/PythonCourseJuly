# %%
#What are modules

# %%
import csv

# %%
file_path="data_students.csv"

# %%
with open(file_path,mode="r") as file:
    csv_reader=csv.reader(file)
    for row in csv_reader:
        # print(type(row))
        print(row)
# Out:
# ['name', 'standard', 'age', 'percentage_marks']
# ['Aarav', '8', '13', '89.5']
# ['Isha', '9', '14', '92.0']
# ['Rahul', '10', '15', '76.5']
# ['Priya', '7', '12', '84.0']
# ['Neha', '11', '16', '91.5']

# %%
def append_csv(file_name,row_data):
    with open(file_name,mode="a",newline="") as file:
        writer=csv.writer(file)
        writer.writerow(row_data)

# %%
append_csv(file_path,["Ishvar",9,14,92.0])

# %%
with open(file_path,mode="r") as file:
    csv_reader=csv.reader(file)
    for row in csv_reader:
        # print(type(row))
        print(row)
# Out:
# ['name', 'standard', 'age', 'percentage_marks']
# ['Aarav', '8', '13', '89.5']
# ['Isha', '9', '14', '92.0']
# ['Rahul', '10', '15', '76.5']
# ['Priya', '7', '12', '84.0']
# ['Neha', '11', '16', '91.5']
# ['Ishvar', '9', '14', '92.0']
# ['Ishvar', '9', '14', '92.0']
