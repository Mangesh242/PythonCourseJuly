# %%
#Dictionary : #unordered , mutable, indexed, cannot contain duplicate keys

# %%
translator= { }  #Curly braces

# %%
type(translator)
# Out:
# dict

# %%
translator["sit"]="basne"

# %%
print(translator["sit"])
# Out:
# basne

# %%
a = { "key" : "value" , "marks":100, "list":[10,80,10]}

# %%
a
# Out:
# {'key': 'value', 'marks': 100, 'list': [10, 80, 10]}

# %%
a['marks']
# Out:
# 100

# %%
a.keys()
# Out:
# dict_keys(['key', 'marks', 'list'])

# %%
a.values()
# Out:
# dict_values(['value', 100, [10, 80, 10]])

# %%
#Information

# %%
#unordered , mutable, indexed, cannot contain duplicate keys

# %%
a[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 a[0]
#
# KeyError: 0

# %%
a["marks"]=99

# %%
a
# Out:
# {'key': 'value', 'marks': 99, 'list': [10, 80, 10]}
