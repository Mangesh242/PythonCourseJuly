# %%
#Tuple are like list, immutable define using : ()

# %%
tuple838=()

# %%
type(tuple838)
# Out:
# tuple

# %%
tuple839=(1)

# %%
type(tuple839)
# Out:
# int

# %%
tuple839=(1,) #To create a tuple with single number

# %%
type(tuple839)
# Out:
# tuple

# %%
tuple840=(10,20,30,20,20,30,40,20,15,20)

# %%
tuple840.count(20)  # Count : occurance of element in a tuple
# Out:
# 5

# %%
#Accesss

# %%
print(tuple840[2])
# Out:
# 30

# %%
tuple840[2]=40
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 tuple840[2]=40
#
# TypeError: 'tuple' object does not support item assignment

# %%
print(len(tuple840))
# Out:
# 10

# %%
#Variable names : camelCasing, camel_casing
