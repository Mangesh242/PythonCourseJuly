# %%
#String

# %%
string="This is my 4th Day"

# %%
print(string[1:-3])
# Out:
# his is my 4th

# %%
#second index in not inclusive , #first index is inclusive

# %%
#[startIndex:endIndex]

# %%
list1=[1,2,3,4,5]

# %%
print(list1[0:3])
# Out:
# [1, 2, 3]

# %%
#stepper | Slicing with skip value

# %%
print(list1[0:-1:1])
# Out:
# [1, 2, 3, 4]

# %%
list1[0:-1:2]
# Out:
# [1, 3]

# %%
'' , "", """ """, ''' '''
# Out:
# ('', '', ' ', ' ')

# %%
string+" 5th day"
# Out:
# 'This is my 4th Day 5th day'

# %%
print(string)  #String is immutable data type
# Out:
# This is my 4th Day

# %%
#CURD of List: Create, Update, Read , Delete

# %%
list827=["ABC",-1,99]

# %%
#Update Operation

# %%
list827[2]=100

# %%
list827
# Out:
# ['ABC', -1, 100]

# %%
#Delete using value and index

# %%
list827.remove(100)

# %%
list827
# Out:
# ['ABC', -1]

# %%
list827.append(100)

# %%
list827
# Out:
# ['ABC', -1, 100]

# %%
del list827[2]

# %%
list827
# Out:
# ['ABC', -1]

# %%
#Empty List

# %%
list827.clear()

# %%
print("Empty list is ", list827)
# Out:
# Empty list is  []

# %%
#Sort, reverse, insert , pop

# %%
list833=[10,40,5,35,22]

# %%
list833.sort()

# %%
list833
# Out:
# [5, 10, 22, 35, 40]

# %%
list833.reverse()

# %%
list833
# Out:
# [40, 35, 22, 10, 5]

# %%
list833.insert(2,38)

# %%
list833
# Out:
# [40, 35, 38, 22, 10, 5]

# %%
list833.pop(2)
# Out:
# 38

# %%
print(list833)
# Out:
# [40, 35, 22, 10, 5]

# %%
22 in list833
# Out:
# True
