# %%
#Assignments

# %%
s = {}

# %%
print(type(s))
# Out:
# <class 'dict'>

# %%
set1={1,}

# %%
type(set1)
# Out:
# set

# %%
# 1. Write a program to store seven fruits in a list entered by the user.

# %%
fruits=[]
fruit=input("Enter first fruit")
# Out:
# Enter first fruit Apple

# %%
fruits.append(fruit)

# %%
fruit=input("Enter fruit")
fruits.append(fruit)
fruit=input("Enter fruit")
fruits.append(fruit)
fruit=input("Enter fruit")
fruits.append(fruit)
fruit=input("Enter fruit")
fruits.append(fruit)
fruit=input("Enter fruit")
fruits.append(fruit)
fruit=input("Enter fruit")
fruits.append(fruit)
# Out:
# Enter fruit Banana
# Enter fruit Kiwi
# Enter fruit Dragon
# Enter fruit Orange
# Enter fruit Chiku
# Enter fruit Pineapple

# %%
print("Fruits list = ",fruits)
# Out:
# Fruits list =  ['Apple', 'Banana', 'Kiwi', 'Dragon', 'Orange', 'Chiku', 'Pineapple']

# %%
#Write a program to accept marks of 6 students and display them in a sorted manner.

# %%
marks=[84,50,60,48,55,41]

# %%
marks.sort()

# %%
marks
# Out:
# [41, 48, 50, 55, 60, 84]

# %%
#3.Demonstrate That Tuples Cannot Be Changed (Immutability)

# %%
tuple1=(10,20,30)

# %%
tuple1[0]=11
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 tuple1[0]=11
#
# TypeError: 'tuple' object does not support item assignment

# %%
#4.Sum a List with 4 Numbers

# %%
numbers=[12,25,7,16]
type(numbers)
# Out:
# list

# %%
sum=0
for i in numbers:
    sum+=i
print("Sum: ",sum)
# Out:
# Sum:  60

# %%
#Count number of zeros

# %%
a = (7, 0, 8, 0, 0, 9)

# %%
a.count(0)
# Out:
# 3

# %%
#Write a program to create a dictionary of Hindi words with values as their English translation. Provide user with an option to look it up!

# %%
dictionary={ "khana":"Eat","Chalana":"Walk"}

# %%
word=input("Enter hindi word")
print(dictionary[word])
# Out:
# Enter hindi word khana
# Eat

# %%
#Write a program to input eight numbers from the user and display all the unique numbers (once).

# %%
list_num=[]

# %%
no=int(input("Enter number"))
if no in list_num:
    print("No is already there in the list")
else:
    list_num.append(no)
# Out:
# Enter number 10

# %%
print(list_num)
# Out:
# [10]

# %%
unique_numbers=set()

# %%
no=int(input("Enter number"))
unique_numbers.add(no)
no=int(input("Enter number"))
unique_numbers.add(no)
no=int(input("Enter number"))
unique_numbers.add(no)
no=int(input("Enter number"))
unique_numbers.add(no)

no=int(input("Enter number"))
unique_numbers.add(no)
no=int(input("Enter number"))
unique_numbers.add(no)
no=int(input("Enter number"))
unique_numbers.add(no)
no=int(input("Enter number"))
unique_numbers.add(no)
# Out:
# Enter number 10
# Enter number 20
# Enter number 30
# Enter number 40
# Enter number 10
# Enter number 20
# Enter number 30
# Enter number 40

# %%
print(unique_numbers)
# Out:
# {40, 10, 20, 30}

# %%
unique_numbers.add(50)

# %%
print(unique_numbers)
# Out:
# {40, 10, 50, 20, 30}

# %%
unique_numbers.append(60)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 unique_numbers.append(60)
#
# AttributeError: 'set' object has no attribute 'append'

# %%
#Create an empty dictionary. Allow 4 friends to enter their favorite language as value and use key as their names. Assume all that the names are unique.
